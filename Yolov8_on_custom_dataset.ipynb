# %%
# !nvidia-smi
# Out:
# Sun Apr 28 19:59:40 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME=os.getcwd()

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 752.1/752.1 kB 15.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !nvidia-smi
# Out:
# Sun Apr 28 20:00:51 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YOLOV8
# Out:
# /content/drive/MyDrive/YOLOV8

# %%
# !ls
# Out:
# data  data.yaml  runs  yolov8n.pt  Yolov8_on_custom_dataset.ipynb

# %%
# %cd /content/drive/MyDrive/YOLOV8
# Out:
# /content/drive/MyDrive/YOLOV8

# %%
# !pip install ultralytics
from ultralytics import YOLO
# !yolo task=detect mode=train model=yolov8s.yaml data=data.yaml epochs=3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 752.1/752.1 kB 5.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.2.4 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 82.3MB/s]
# val: Scanning /content/drive/MyDrive/YOLOV8/data/valid/labels.cache... 197 images, 4 backgrounds, 0 corrupt: 100% 197/197 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/YOLOV8/data/valid/images/0427_mp4-0006_jpg.rf.4ade961f03419729c1a8998bd0d3e907.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/drive/MyDrive/YOLOV8/data/valid/images/6_mp4-0118_jpg.rf.2d9adafc2e4e57a2d32925c4da192fc0.jpg: 1 duplicate labels removed
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 1264, len(boxes) = 1289. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# ...

# %% [markdown]
# # Checking how custom models works

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=data/test/images
# Out:
# Ultralytics YOLOv8.2.4 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/97 /content/drive/MyDrive/YOLOV8/data/test/images/0427_mp4-0002_jpg.rf.42f09e343dfe86c75b483c36997278dc.jpg: 640x640 1 Fruit, 16.4ms
# image 2/97 /content/drive/MyDrive/YOLOV8/data/test/images/0427_mp4-0004_jpg.rf.621e8484bf04a17e8564d85af6cf14fe.jpg: 640x640 1 Fruit, 16.4ms
# image 3/97 /content/drive/MyDrive/YOLOV8/data/test/images/0427_mp4-0008_jpg.rf.82bccaa163e8073df1662b34c898c737.jpg: 640x640 1 Fruit, 16.4ms
# image 4/97 /content/drive/MyDrive/YOLOV8/data/test/images/0427_mp4-0021_jpg.rf.617f74fb5b26bfefc088607031546467.jpg: 640x640 1 Fruit, 16.4ms
# image 5/97 /content/drive/MyDrive/YOLOV8/data/test/images/0427_mp4-0023_jpg.rf.241a1379f8cfc84d83f28daff06dd897.jpg: 640x640 1 Fruit, 16.4ms
# ...
